# %% [markdown]
# <a href="https://colab.research.google.com/github/Felista-Mueni/Teal-dear/blob/master/Introduction_to_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as pd

# %% [markdown]
# # ***Import the firts library***
#
# `import numpy as pd`
#
# import numpy as pd

# %%
df = pd.read_csv('/content/weekly_inventories (1).csv')
df.head()
# Out:
#          Date  Inventories
# 0  2024-04-12       3299.0
# 1  2025-01-31       3224.0
# 2  2024-10-18       2299.0
# 3  2024-03-08       4221.0
# 4  2010-06-18       3685.0

# %%
import kagglehub
path = kagglehub.dataset_download("puneet6060/intel-image-classification")
# Out:
# Using Colab cache for faster access to the 'intel-image-classification' dataset.
